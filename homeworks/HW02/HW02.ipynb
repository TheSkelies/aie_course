# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dataSet = pd.read_csv("S02-hw-dataset.csv")

# %%
dataSet.head(5) # первые 5 строк датасета
# Out:
#    user_id   age country  purchases  revenue
# 0        1  25.0      FR          7      749
# 1        2  24.0      RU          5     1115
# 2        3  52.0      FR          7      399
# 3        4  31.0      RU          6      654
# 4        5   NaN      DE          6     1296

# %%
dataSet.info() # вывод информации о стообцах и типах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    41 non-null     int64
#  1   age        39 non-null     float64
#  2   country    41 non-null     object
#  3   purchases  41 non-null     int64
#  4   revenue    41 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.7+ KB

# %%
dataSet.describe() # описание статистики
# Out:
#          user_id         age  purchases      revenue
# count  41.000000   39.000000  41.000000    41.000000
# mean   20.243902   36.512821   4.829268   820.048780
# std    11.659289   18.304259   2.710189   613.127269
# min     1.000000    5.000000  -1.000000     0.000000
# 25%    10.000000   24.000000   3.000000   432.000000
# 50%    20.000000   33.000000   5.000000   693.000000
# 75%    30.000000   45.500000   7.000000  1115.000000
# max    40.000000  120.000000  11.000000  2475.000000

# %%
dataSet.isna().mean() # доля пустых значений в столбцах
# Out:
# user_id      0.00000
# age          0.04878
# country      0.00000
# purchases    0.00000
# revenue      0.00000
# dtype: float64

# %%
dataSet.duplicated() # вывод дупликатов
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40     True
# dtype: bool

# %%
dataSet.loc[dataSet['purchases'] < 0, 'user_id'] # вывод индекс и id пользователя, где продаж меньше 0
# Out:
# 5    6
# Name: user_id, dtype: int64

# %%
condition = (dataSet['purchases'] != 0) & (dataSet['revenue'] == 0)
dataSet.loc[condition, 'user_id'] # вывод индекс и id пользователя, где доход нулевой при не нулевых продажах
# Out:
# 10    11
# Name: user_id, dtype: int64

# %%
dataSet.loc[dataSet['age'] > 100, 'user_id'] # вывод индекс и id пользователя, где возраст больше 100
# Out:
# 5    6
# Name: user_id, dtype: int64

# %% [markdown]
# Проблемой этих данных является противоречивость данных

# %%
dataSet['country'].value_counts() # количество пользователей из каждой из стран
# Out:
# country
# RU    13
# FR    12
# US     8
# DE     6
# CN     2
# Name: count, dtype: int64

# %%
dataSet.groupby('country')['purchases'].sum() # количество продаж из каждой страны
# Out:
# country
# CN     9
# DE    39
# FR    51
# RU    62
# US    37
# Name: purchases, dtype: int64

# %% [markdown]
# В качественной категории стран доминируют "RU" и "FR", а в количественной категории продаж доминируют также "RU" и "FR" со значениями 62 и 51 соответственно

# %%
plt.hist(dataSet['age'], bins=30)
plt.xlabel('Возраст')
plt.ylabel('Частота появления')
plt.title('Гистограмма распределения')
plt.savefig('figures/Distribution histogram')
plt.show()

# %%
plt.boxplot(dataSet['revenue'])
plt.ylabel('Значения')
plt.title("Доход")
plt.savefig('figures/boxplot')
plt.show()

# %%
plt.scatter(dataSet['age'], dataSet['purchases'])
plt.xlabel('Возраст')
plt.ylabel('Продажи')
plt.title('Зависимость продаж от возраста')
plt.savefig('figures/scatter')
plt.show()
